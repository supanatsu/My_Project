# %% [markdown]
# <a href="https://colab.research.google.com/github/supanatsu/My_Project/blob/main/Final_project_Data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/pycaret/pycaret.git@master pycaret[mlops]
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.6/169.6 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.9/109.9 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.6/139.6 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 21.9 MB/s eta 0:00:00
# ...

# %%
# !pip install -q mlflow

import mlflow

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %% [markdown]
# Business Understanding
# 1.   ปัจจัยอะไรที่ส่งผลกระทบต่อสุขภาพจิตมากที่สุด
# 2.เราสามารถแบ่งประชากรออกเป็นกลุ่มที่มีความเสี่ยงต่างกันได้หรือไม่?
# 3.   Cluster ไหนมีแนวโน้มสุขภาพจิตแย่ที่สุด และแต่ละ Cluster มีลักษณะพฤติกรรมที่แตกต่างกันอย่างไร?

# %% [markdown]
# Data Understanding

# %%
import pandas as pd

mydata = pd.read_csv("/content/sample_data/my_data.csv")
mydata
# Out:
#     Regional       Province           District  Sub-District Gender  Age  \
# 0    ภาคกลาง  กรุงเทพมหานคร         เขตหนองจอก       ลำผักชี   หญิง   61
# 1    ภาคกลาง  กรุงเทพมหานคร           เขตบางแค         บางแค   หญิง   26
# 2    ภาคกลาง  กรุงเทพมหานคร        เขตทวีวัฒนา  ศาลาธรรมสพน์   หญิง   55
# 3    ภาคกลาง  กรุงเทพมหานคร         เขตบางซื่อ     วงศ์สว่าง   หญิง   64
# 4    ภาคกลาง  กรุงเทพมหานคร          เขตประเวศ        ดอกไม้    ชาย   33
# ..       ...            ...                ...           ...    ...  ...
# 559   ภาคใต้           สตูล               ละงู         กำแพง    ชาย   25
# 560   ภาคใต้           สตูล          เมืองสตูล         พิมาน    ชาย   47
# 561   ภาคใต้   สุราษฎร์ธานี            วิภาวดี    ตะกุกเหนือ    ชาย   39
# 562   ภาคใต้   สุราษฎร์ธานี  เมืองสุราษฎร์ธานี    มะขามเตี้ย    ชาย   40
# 563   ภาคใต้   สุราษฎร์ธานี         กาญจนดิษฐ์    ท่าทองใหม่    ชาย   64
#
#                        Age Range    Relation    Mariage Registration  Alcohol  \
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 0 to 563
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Regional              564 non-null    object
#  1   Province              564 non-null    object
#  2   District              564 non-null    object
#  3   Sub-District          564 non-null    object
#  4   Gender                564 non-null    object
#  5   Age                   564 non-null    int64
#  6   Age Range             564 non-null    object
#  7   Relation              564 non-null    object
#  8   Mariage Registration  564 non-null    object
#  9   Alcohol               564 non-null    int64
#  10  Drug                  564 non-null    int64
#  11  Authoritative         564 non-null    int64
#  12  Rage                  564 non-null    int64
#  13  Jealous               564 non-null    int64
#  14  Divorce               564 non-null    int64
# ...

# %%
mydata.isna().sum()
# Out:
# Regional                0
# Province                0
# District                0
# Sub-District            0
# Gender                  0
# Age                     0
# Age Range               0
# Relation                0
# Mariage Registration    0
# Alcohol                 0
# Drug                    0
# Authoritative           0
# Rage                    0
# Jealous                 0
# Divorce                 0
# Health Problem          0
# Mental Problem          0
# Gambling Addict         0
# Economics Stress        0
# dtype: int64

# %%
mydata.describe()
# Out:
#               Age     Alcohol        Drug  Authoritative        Rage  \
# count  564.000000  564.000000  564.000000     564.000000  564.000000
# mean    40.218085    0.320922    0.368794       0.260638    0.297872
# std     12.884938    0.467245    0.482906       0.439373    0.457729
# min     10.000000    0.000000    0.000000       0.000000    0.000000
# 25%     31.000000    0.000000    0.000000       0.000000    0.000000
# 50%     39.000000    0.000000    0.000000       0.000000    0.000000
# 75%     48.250000    1.000000    1.000000       1.000000    1.000000
# max     84.000000    1.000000    1.000000       1.000000    1.000000
#
#           Jealous     Divorce  Health Problem  Mental Problem  \
# count  564.000000  564.000000      564.000000      564.000000
# mean     0.205674    0.031915        0.033688        0.159574
# std      0.404552    0.175930        0.180585        0.366536
# min      0.000000    0.000000        0.000000        0.000000
# ...

# %%
mydata.describe(include='object').T
# Out:
#                      count unique                   top freq
# Regional               564      4               ภาคกลาง  257
# Province               564     69         กรุงเทพมหานคร   59
# District               564    303          เมืองราชบุรี   14
# Sub-District           564    453               ในเมือง   10
# Gender                 564      3                   ชาย  461
# Age Range              564      5  วัยกลางคน 36 - 59 ปี  287
# Relation               564      4                  สมรส  259
# Mariage Registration   564      5               ไม่ระบุ  216

# %%
numeric_columns = mydata.select_dtypes('number')
categorical_columns = mydata.select_dtypes('object')

# %%
numeric_columns
# Out:
#      Age  Alcohol  Drug  Authoritative  Rage  Jealous  Divorce  \
# 0     61        0     0              0     1        0        0
# 1     26        0     0              0     1        0        0
# 2     55        0     0              0     0        0        0
# 3     64        0     0              1     1        0        0
# 4     33        1     0              0     1        1        0
# ..   ...      ...   ...            ...   ...      ...      ...
# 559   25        1     1              0     0        0        0
# 560   47        0     1              0     0        0        0
# 561   39        0     1              0     0        1        0
# 562   40        1     1              0     0        1        0
# 563   64        1     1              0     1        0        0
#
#      Health Problem  Mental Problem  Gambling Addict  Economics Stress
# 0                 0               0                0                 0
# ...

# %%
categorical_columns
# Out:
#     Regional       Province           District  Sub-District Gender  \
# 0    ภาคกลาง  กรุงเทพมหานคร         เขตหนองจอก       ลำผักชี   หญิง
# 1    ภาคกลาง  กรุงเทพมหานคร           เขตบางแค         บางแค   หญิง
# 2    ภาคกลาง  กรุงเทพมหานคร        เขตทวีวัฒนา  ศาลาธรรมสพน์   หญิง
# 3    ภาคกลาง  กรุงเทพมหานคร         เขตบางซื่อ     วงศ์สว่าง   หญิง
# 4    ภาคกลาง  กรุงเทพมหานคร          เขตประเวศ        ดอกไม้    ชาย
# ..       ...            ...                ...           ...    ...
# 559   ภาคใต้           สตูล               ละงู         กำแพง    ชาย
# 560   ภาคใต้           สตูล          เมืองสตูล         พิมาน    ชาย
# 561   ภาคใต้   สุราษฎร์ธานี            วิภาวดี    ตะกุกเหนือ    ชาย
# 562   ภาคใต้   สุราษฎร์ธานี  เมืองสุราษฎร์ธานี    มะขามเตี้ย    ชาย
# 563   ภาคใต้   สุราษฎร์ธานี         กาญจนดิษฐ์    ท่าทองใหม่    ชาย
#
#                        Age Range    Relation    Mariage Registration
# 0         วัยสูงอายุ 60 ปีขึ้นไป         โสด                 ไม่ระบุ
# ...

# %%
for col in categorical_columns:
  print(mydata[col].value_counts(), '\n')
# Out:
# Regional
# ภาคกลาง                  257
# ภาคตะวันออกเฉียงเหนือ    133
# ภาคเหนือ                 115
# ภาคใต้                    59
# Name: count, dtype: int64
#
# Province
# กรุงเทพมหานคร    59
# ราชบุรี          48
# ฉะเชิงเทรา       19
# น่าน             19
# หนองคาย          16
#                  ..
# เลย               1
# สมุทรสงคราม       1
# สมุทรปราการ       1
# ปราจีนบุรี        1
# ยะลา              1
# Name: count, Length: 69, dtype: int64
#
# District
# เมืองราชบุรี    14
# โพธาราม         12
# เมืองหนองคาย     9
# เมืองระยอง       8
# เมืองพิจิตร      7
#                 ..
# เขาย้อย          1
# กุฉินารายณ์      1
# สหัสขันธ์        1
# คำม่วง           1
# กาญจนดิษฐ์       1
# Name: count, Length: 303, dtype: int64
#
# Sub-District
# ในเมือง       10
# โพธิ์ชัย       5
# มุกดาหาร       5
# หมากแข้ง       4
# บางมด          4
#               ..
# พุคำจาน        1
# ท่าจีน         1
# อ้อมน้อย       1
# โกรกกราก       1
# ท่าทองใหม่     1
# ...

# %% [markdown]
# Data Preparation

# %%
pref_data = mydata.copy()

# %%
from sklearn.preprocessing import LabelEncoder

categorical_columns = ['Regional', 'Province', 'District', 'Sub-District', 'Gender', 'Age Range', 'Relation', 'Mariage Registration']
les = dict()
for col in categorical_columns:
    le = LabelEncoder()
    pref_data[col] = le.fit_transform(pref_data[col].astype(str))  # แปลงเป็น string ก่อนเผื่อมีค่า NaN
    les[col] = le

# %%
pd.to_pickle(les, 'les.pkl')

# %%
pref_data.drop(columns=['Column1'], errors='ignore', inplace=True)
pref_data
# Out:
#      Regional  Province  District  Sub-District  Gender  Age  Age Range  \
# 0           0         1       206           246       1   61          3
# 1           0         1       192           154       1   26          1
# 2           0         1       183           274       1   55          0
# 3           0         1       188           248       1   64          3
# 4           0         1       193            45       0   33          1
# ..        ...       ...       ...           ...     ...  ...        ...
# 559         3        47       124             6       0   25          1
# 560         3        47       254           224       0   47          0
# 561         3        55       134            68       0   39          0
# 562         3        55       262           229       0   40          0
# 563         3        55         2            94       0   64          3
#
#      Relation  Mariage Registration  Alcohol  Drug  Authoritative  Rage  \
# ...

# %%
# สร้างฟีเจอร์ใหม่โดยรวมคอลัมน์ที่เกี่ยวข้อง

pref_data["Substance Use"] = pref_data["Alcohol"] + pref_data["Drug"]
pref_data["Aggression"] = pref_data["Authoritative"] + pref_data["Rage"]
pref_data["Relationship Issues"] = pref_data["Jealous"] + pref_data["Divorce"]
pref_data["Health Issues"] = pref_data["Health Problem"] + pref_data["Mental Problem"]
pref_data["Financial Issues"] = pref_data["Gambling Addict"] + pref_data["Economics Stress"]

# ลบคอลัมน์เดิมที่ถูกใช้ไปรวมแล้ว
pref_data.drop(columns=["Alcohol", "Drug", "Authoritative", "Rage", "Jealous", "Divorce",
                 "Health Problem", "Mental Problem", "Gambling Addict", "Economics Stress"], inplace=True)
pref_data
# Out:
#      Regional  Province  District  Sub-District  Gender  Age  Age Range  \
# 0           0         1       206           246       1   61          3
# 1           0         1       192           154       1   26          1
# 2           0         1       183           274       1   55          0
# 3           0         1       188           248       1   64          3
# 4           0         1       193            45       0   33          1
# ..        ...       ...       ...           ...     ...  ...        ...
# 559         3        47       124             6       0   25          1
# 560         3        47       254           224       0   47          0
# 561         3        55       134            68       0   39          0
# 562         3        55       262           229       0   40          0
# 563         3        55         2            94       0   64          3
#
#      Relation  Mariage Registration  Substance Use  Aggression  \
# ...

# %% [markdown]
# Modeling

# %%
from pycaret.clustering import *

# %%
pref_models = setup(
    data=pref_data,
    session_id=123,
    ignore_features=['Province', 'District', 'Sub-District', 'Gender', 'Age Range', 'Relation', 'Mariage Registration']
)
# Out:
# <style type="text/css">
# #T_78dd2_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78dd2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78dd2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_78dd2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78dd2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78dd2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_78dd2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_78dd2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78dd2_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_78dd2_row1_col1" class="data row1 col1" >(564, 14)</td>
#     </tr>
#     <tr>
# ...

# %%
pref_models.models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# birch                           sklearn.cluster._birch.Birch

# %%
models = {
    "KMeans": create_model('kmeans', num_clusters=3),
    "DBSCAN": create_model('dbscan'),
    "Hierarchical": create_model('hclust'),
    "Affinity Propagation": create_model('ap'),
    "Mean Shift": create_model('meanshift'),
    "Spectral Clustering": create_model('sc'),
    "OPTICS": create_model('optics'),
    "Birch": create_model('birch')
}
# Out:
# <style type="text/css">
# </style>
# <table id="T_90a5b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90a5b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_90a5b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_90a5b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_90a5b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_90a5b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_90a5b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90a5b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90a5b_row0_col0" class="data row0 col0" >0.4982</td>
#       <td id="T_90a5b_row0_col1" class="data row0 col1" >1203.8465</td>
# ...

# %%
best_model = create_model("kmeans",num_clusters=3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_63398" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63398_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_63398_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_63398_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_63398_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_63398_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_63398_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63398_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63398_row0_col0" class="data row0 col0" >0.4982</td>
#       <td id="T_63398_row0_col1" class="data row0 col1" >1203.8465</td>
# ...

# %% [markdown]
# Evaluation

# %%
selected_model = models["KMeans"]
pref_clustered = assign_model(selected_model)
pref_clustered
# Out:
#      Regional  Age  Substance Use  Aggression  Relationship Issues  \
# 0           0   61              0           1                    0
# 1           0   26              0           1                    0
# 2           0   55              0           0                    0
# 3           0   64              0           2                    0
# 4           0   33              1           1                    1
# ..        ...  ...            ...         ...                  ...
# 559         3   25              2           0                    0
# 560         3   47              1           0                    0
# 561         3   39              1           0                    1
# 562         3   40              2           0                    1
# 563         3   64              2           1                    0
#
#      Health Issues  Financial Issues    Cluster
# 0                0                 0  Cluster 1
# 1                0                 0  Cluster 0
# ...

# %%
pref_models.evaluate_model(selected_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
pref_clustered.to_csv('pref_data.csv', index=False)

# %% [markdown]
# Deployment

# %%
final_model = assign_model(selected_model)

# %%
save_model(final_model, 'final_cluster_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Regional', 'Age', 'Substance Use',
#                                               'Aggression',
#                                               'Relationship Issues',
#                                               'Health Issues',
#                                               'Financial Issues'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model',
#                        Regional  Age  Substance Use  Aggression  Relationship Issues  \
#  0           0   61              0           1                    0
# ...

# %%
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 29.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 67.6 MB/s eta 0:00:00

# %%
# %%writefile test.py
import streamlit as st
import pandas as pd
import numpy as np
import json
import joblib
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import euclidean_distances

# โหลดข้อมูลจาก CSV แล้วลบคอลัมน์ที่ไม่ต้องการ ("dtype", "Regional")
try:
    final_cluster_data = pd.read_csv("/content/sample_data/pref_data.csv")
    final_cluster_data = final_cluster_data.drop(columns=["dtype", "Regional"], errors="ignore")
    st.sidebar.success("Successfully loaded clustering data from /content/sample_data/pref_data.csv")

    st.sidebar.info(f"Data shape: {final_cluster_data.shape}")
    if 'Cluster' in final_cluster_data.columns:
        st.sidebar.info(f"Found {final_cluster_data['Cluster'].nunique()} clusters in the data")
except Exception as e:
    st.sidebar.error(f"Error loading CSV data: {e}")
    st.stop()

# โหลดข้อมูลภูมิภาค
try:
    with open("/content/sample_data/region_province_district_subdistrict.json", "r", encoding="utf-8") as f:
        region_data = json.load(f)
    st.sidebar.success("Successfully loaded region data")
except Exception as e:
    st.sidebar.error(f"Error loading region data: {e}")
    st.stop()

# โหลด label encoders (หากใช้งาน)
try:
    les = joblib.load("/content/les.pkl")
    st.sidebar.success("Successfully loaded label encoders")
except Exception as e:
    st.sidebar.error(f"Error loading label encoders: {e}")
    st.stop()

st.title("🔍 Clustering Web App")

# การเลือกภูมิภาค (ข้อมูลส่วนนี้แสดงเพื่อความสะดวก แต่ไม่ใช้คำนวณคลัสเตอร์)
region = st.selectbox("เลือกภาค", options=list(region_data.keys()))
province = st.selectbox("เลือกจังหวัด", options=list(region_data[region].keys()))
district = st.selectbox("เลือกอำเภอ", options=list(region_data[region][province].keys()))
subdistrict = st.selectbox("เลือกตำบล", options=region_data[region][province][district])

with st.form('clustering_form'):
    # เก็บข้อมูลส่วนภูมิศาสตร์เพื่อแสดง แต่จะไม่ใช้คำนวณคลัสเตอร์
    new_data = {
        "Region": region,
        "Province": province,
        "District": district,
        "Sub-District": subdistrict
    }

    # ฟีเจอร์สำหรับการกรอกข้อมูล (ส่วนที่มีผลต่อการ clustering)
    # หมายเหตุ: 'Mariage Registration' และ 'Relation' แม้ว่าจะกรอกเข้ามาแต่จะไม่ใช้คำนวณ clustering
    feature_columns = ["Age", "Mariage Registration", "Relation", "Substance Use",
                       "Aggression", "Relationship Issues", "Health Issues", "Financial Issues"]

    for col in feature_columns:
        if col == "Age":
            new_data[col] = st.number_input("อายุ", min_value=10, max_value=100, step=1, format="%d")
        elif col == "Mariage Registration":
            new_data[col] = st.radio(col, options=["ไม่จด", "จดทะเบียน"])
        elif col == "Relation":
            new_data[col] = st.radio(col, options=["โสด", "สมรส", "หย่าร้าง"])
        elif col in ["Substance Use", "Aggression", "Relationship Issues", "Health Issues", "Financial Issues"]:
            value = st.number_input(col,min_value=0, max_value=1, step=1)
            new_data[col] = 1 if value > 0 else 0
        else:
            new_data[col] = st.number_input(col, min_value=0, max_value=100, step=1)

    submit = st.form_submit_button("🔮 Predict Cluster")

    if submit:
        # สร้าง DataFrame จากข้อมูลที่กรอกเข้ามา
        new_df = pd.DataFrame([new_data])

        # แปลงข้อมูล categorical ให้เป็นตัวเลข
        mapping = {
            "ไม่จด": 0, "จดทะเบียน": 1,
            "โสด": 0, "สมรส": 1, "หย่าร้าง": 2
        }
        for col in ["Mariage Registration", "Relation"]:
            if col in new_df.columns:
                new_df[col] = new_df[col].map(lambda x: mapping.get(x, 0))

        # แสดงคอลัมน์ในข้อมูลอ้างอิง
        ref_cols = final_cluster_data.columns.tolist()
        # st.write("### 📋 คอลัมน์ในข้อมูลอ้างอิง:")
        # st.write(", ".join(ref_cols))

        st.write("### 📝 ข้อมูลที่กรอก:")
        st.dataframe(new_df)

        try:
            # ระบุคอลัมน์ที่ไม่มีผลต่อการ clustering
            irrelevant_cols = ['Province', 'District', 'Sub-District', 'Gender', 'Age Range', 'Relation', 'Mariage Registration']

            # เตรียมข้อมูลสำหรับการวิเคราะห์ โดยไม่รวมคอลัมน์ "Cluster", "Regional" และคอลัมน์ที่ไม่มีผลต่อ clustering
            input_for_clustering = pd.DataFrame()
            for col in ref_cols:
                if col in ['Cluster', 'Regional'] or col in irrelevant_cols:
                    continue
                if col in new_df.columns:
                    input_for_clustering[col] = new_df[col]
                else:
                    input_for_clustering[col] = 0

            st.write("### 🔍 ข้อมูลที่ใช้ในการวิเคราะห์ (เฉพาะฟีเจอร์ที่มีผล):")
            st.dataframe(input_for_clustering)

            # กำหนดคอลัมน์ที่ใช้สำหรับวิเคราะห์
            feature_cols = input_for_clustering.columns.tolist()
            if not feature_cols:
                st.error("ไม่พบคอลัมน์ที่สามารถใช้วิเคราะห์ได้")
                st.stop()

            reference_features = final_cluster_data[feature_cols]
            input_features = input_for_clustering[feature_cols]

            # st.write("### 📊 คอลัมน์ที่ใช้สำหรับการวิเคราะห์:")
            # st.write(", ".join(feature_cols))

            # คำนวณระยะห่างแบบ Euclidean
            distances = euclidean_distances(input_features, reference_features)
            most_similar_idx = np.argmin(distances[0])

            # ดึงค่า Cluster จากข้อมูลอ้างอิง (ถ้ามีคอลัมน์ Cluster)
            if 'Cluster' in final_cluster_data.columns:
                assigned_cluster = final_cluster_data.iloc[most_similar_idx]['Cluster']
                # หาก assigned_cluster เป็นสตริงที่มี "Cluster " นำหน้า ให้ตัดออก
                if isinstance(assigned_cluster, str) and assigned_cluster.startswith("Cluster"):
                    try:
                        assigned_cluster = int(assigned_cluster.replace("Cluster", "").strip())
                    except Exception as e:
                        st.error(f"ไม่สามารถแปลงค่า cluster ได้: {e}")
                        st.stop()
            else:
                combined_data = pd.concat([reference_features, input_features], ignore_index=True)
                model = AgglomerativeClustering(n_clusters=3)
                clusters = model.fit_predict(combined_data)
                assigned_cluster = clusters[-1]

            st.subheader(f"📌 คุณถูกจัดอยู่ในกลุ่มที่: **Cluster {assigned_cluster}**")
            st.write(f"ระยะห่างจากจุดอ้างอิงใกล้เคียงที่สุด: {distances[0][most_similar_idx]:.2f}")

            st.write("### 📊 ลักษณะของกลุ่ม:")
            if int(assigned_cluster) == 0:
                st.info("Cluster 0: กลุ่มที่มีความเสี่ยงต่ำ")
            elif int(assigned_cluster) == 1:
                st.warning("Cluster 1: กลุ่มที่มีความเสี่ยงปานกลาง")
            elif int(assigned_cluster) == 2:
                st.error("Cluster 2: กลุ่มที่มีความเสี่ยงสูง")
            else:
                st.info(f"Cluster {assigned_cluster}: ไม่มีข้อมูลเพิ่มเติมสำหรับกลุ่มนี้")

            # แสดงข้อมูลอ้างอิงที่ใกล้เคียงที่สุด (รวม Cluster ด้วย)
            st.write("### 📊 ข้อมูลอ้างอิงที่ใกล้เคียงที่สุด:")
            similar_data = final_cluster_data.iloc[most_similar_idx].to_frame().T
            st.dataframe(similar_data)

        except Exception as e:
            st.error(f"เกิดข้อผิดพลาดในการทำนาย: {e}")
            st.info("รายละเอียดเพิ่มเติม:")
            import traceback
            st.code(traceback.format_exc())
            st.write("### 📋 ตัวอย่างข้อมูลอ้างอิง:")
            st.dataframe(final_cluster_data.head())
# Out:
# Writing test.py

# %%
# !npm install localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 22 packages in 3s
# ⠙
# ⠙3 packages are looking for funding
# ⠙  run `npm fund` for details
# ⠙

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.106.189.40

# %%
# !streamlit run test.py & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.189.40:8501
#
# your url is: https://good-regions-beam.loca.lt
#   Stopping...
# ^C
